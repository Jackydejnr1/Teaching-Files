# %% [markdown]
# <a href="https://colab.research.google.com/github/Jackydejnr1/Teaching-Files/blob/main/connect_to_sqlite_database.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Import file from your system
from google.colab import files
uploaded = files.upload()

#connect with sqlite database
#import necessary libraries
import sqlite3

database = 'database.sqlite'
conn = sqlite3.connect(database)
print('Opened data successfully')

#read sql query for getting all the tables of database into dataframe
#here select* means select all
import pandas as pd
tables = pd.read_sql("""select *
                from sqlite_master
                where type='table';""", conn)
tables
# Out:
#      <input type="file" id="files-67b3a73d-0bde-4856-a13e-113616e99240" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-67b3a73d-0bde-4856-a13e-113616e99240">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
Matches = pd.read_sql("""SELECT *
                         FROM SQLITE_MASTER
                         WHERE type= 'table';""", conn)
Matches
# Out:
#      type             name         tbl_name  rootpage  \
# 0   table           Player           Player         2
# 1   table       Extra_Runs       Extra_Runs         3
# 2   table   Batsman_Scored   Batsman_Scored         7
# 3   table    Batting_Style    Batting_Style        10
# 4   table    Bowling_Style    Bowling_Style        11
# 5   table          Country          Country        12
# 6   table           Season           Season        14
# 7   table             City             City        15
# 8   table          Outcome          Outcome        16
# 9   table           Win_By           Win_By        17
# 10  table     Wicket_Taken     Wicket_Taken        18
# 11  table            Venue            Venue        21
# 12  table       Extra_Type       Extra_Type        23
# 13  table         Out_Type         Out_Type        24
# 14  table    Toss_Decision    Toss_Decision        25
# 15  table           Umpire           Umpire        26
# ...

# %%
display(Matches)
# Out:
#      type             name         tbl_name  rootpage  \
# 0   table           Player           Player         2
# 1   table       Extra_Runs       Extra_Runs         3
# 2   table   Batsman_Scored   Batsman_Scored         7
# 3   table    Batting_Style    Batting_Style        10
# 4   table    Bowling_Style    Bowling_Style        11
# 5   table          Country          Country        12
# 6   table           Season           Season        14
# 7   table             City             City        15
# 8   table          Outcome          Outcome        16
# 9   table           Win_By           Win_By        17
# 10  table     Wicket_Taken     Wicket_Taken        18
# 11  table            Venue            Venue        21
# 12  table       Extra_Type       Extra_Type        23
# 13  table         Out_Type         Out_Type        24
# 14  table    Toss_Decision    Toss_Decision        25
# 15  table           Umpire           Umpire        26
# ...

# %%
#Check team id of all team
teams = pd.read_sql("""SELECT *
                         FROM Team;""",conn)
teams
# Out:
#     Team_Id                    Team_Name
# 0         1        Kolkata Knight Riders
# 1         2  Royal Challengers Bangalore
# 2         3          Chennai Super Kings
# 3         4              Kings XI Punjab
# 4         5             Rajasthan Royals
# 5         6             Delhi Daredevils
# 6         7               Mumbai Indians
# 7         8              Deccan Chargers
# 8         9         Kochi Tuskers Kerala
# 9        10                Pune Warriors
# 10       11          Sunrisers Hyderabad
# 11       12      Rising Pune Supergiants
# 12       13                Gujarat Lions

# %%
#read tables from the dataset into data frame
Matches = pd.read_sql("""SELECT *
                         FROM Match;""",conn)
"""**conclution - **
- 12 Numeric features (Integer and Numeric)and one categorical feature (text)
-3 columns with null features
"""
Matches
# Out:
#      Match_Id  Team_1  Team_2           Match_Date  Season_Id  Venue_Id  \
# 0      335987       2       1  2008-04-18 00:00:00          1         1
# 1      335988       4       3  2008-04-19 00:00:00          1         2
# 2      335989       6       5  2008-04-19 00:00:00          1         3
# 3      335990       7       2  2008-04-20 00:00:00          1         4
# 4      335991       1       8  2008-04-20 00:00:00          1         5
# ..        ...     ...     ...                  ...        ...       ...
# 572    981016       6       2  2016-05-22 00:00:00          9        27
# 573    981018      13       2  2016-05-24 00:00:00          9         1
# 574    981020      11       1  2016-05-25 00:00:00          9         3
# 575    981022      13      11  2016-05-27 00:00:00          9         3
# 576    981024       2      11  2016-05-29 00:00:00          9         1
#
#      Toss_Winner  Toss_Decide  Win_Type  Win_Margin  Outcome_type  \
# ...

# %%
#check the details of all matvhes won by mumbian Indians
Mi_wins = pd.read_sql("""SELECT *
                         FROM Match
                         WHERE Match_Winner = 7;""",conn)
Mi_wins
# Out:
#     Match_Id  Team_1  Team_2           Match_Date  Season_Id  Venue_Id  \
# 0     336002       1       7  2008-04-29 00:00:00          1         5
# 1     336009       7       6  2008-05-04 00:00:00          1         9
# 2     336013       7       5  2008-05-07 00:00:00          1         9
# 3     336017       2       7  2008-05-28 00:00:00          1         1
# 4     336023       7       3  2008-05-14 00:00:00          1         4
# ..       ...     ...     ...                  ...        ...       ...
# 75    980946       4       7  2016-04-25 00:00:00          9        33
# 76    980952       7       1  2016-04-28 00:00:00          9         4
# 77    980962      12       7  2016-05-01 00:00:00          9        32
# 78    980986       2       7  2016-05-11 00:00:00          9         1
# 79    980998       7       6  2016-05-15 00:00:00          9        25
#
#     Toss_Winner  Toss_Decide  Win_Type  Win_Margin  Outcome_type  \
# ...

# %%
#chack details of all the matches won by mumbai Indians in last 2 seasons
MI_S8_S9 = pd.read_sql("""SELECT *
                         FROM Match
                         WHERE MATCH_WINNER =7
                         AND SEASON_ID IN (8,9);""",conn)
MI_S8_S9
# Out:
#     Match_Id  Team_1  Team_2           Match_Date  Season_Id  Venue_Id  \
# 0     829742       2       7  2015-04-19 00:00:00          8         1
# 1     829756       7      11  2015-04-25 00:00:00          8         4
# 2     829774       7       5  2015-05-01 00:00:00          8         4
# 3     829780       4       7  2015-05-03 00:00:00          8         2
# 4     829788       7       6  2015-05-05 00:00:00          8         4
# 5     829794       3       7  2015-05-08 00:00:00          8         8
# 6     829810       7       1  2015-05-14 00:00:00          8         4
# 7     829820      11       7  2015-05-17 00:00:00          8         7
# 8     829822       3       7  2015-05-19 00:00:00          8         4
# 9     829828       7       3  2015-05-24 00:00:00          8         5
# 10    980914       1       7  2016-04-13 00:00:00          9         5
# 11    980932       7       2  2016-04-20 00:00:00          9         4
# ...

# %%
Newteam = pd.read_sql("""SELECT *
                         FROM Team
                         where Team_Name like'De%';""",conn)
Newteam
# Out:
#    Team_Id         Team_Name
# 0        6  Delhi Daredevils
# 1        8   Deccan Chargers

# %%
#Check the minimum and maximum win margin of all the matches
min_max_margin = pd.read_sql("""SELECT MIN(WIN_MARGIN),MAX(WIN_MARGIN)
                         FROM Match;""",conn)
min_max_margin
# Out:
#    MIN(WIN_MARGIN)  MAX(WIN_MARGIN)
# 0                1              144

# %% [markdown]
# Part 2: Here we showcase the use of more SQL Statements like Distinct, Order by, Groupby and aggregation.

# %%
Matches.head()
"""**conclutiom-**
-12 NUWERIC FEATURES INTEGER (Nunreric and integer) and three categorical features (text)
-3 columns with null expressions
"""
#get the average win margins for all the wining teams for season 9
result1 = pd.read_sql("""SELECT AVG(WIN_MARGIN),Match_Winner
                         FROM Match
                         WHERE SEASON_ID = 9
                         group by Match_Winner;""",conn)
result1

#get the count of the venues for season 9
result2 = pd.read_sql("""SELECT COUNT(DISTINCT VENUE_ID)
                         FROM Match
                         WHERE SEASON_ID = 9;""",conn)
result2
#get the minimum ,maximum and average win margin
#also get the total number of players who have recieved man of the match throughout all the seasons
result3 = pd.read_sql("""SELECT MIN(WIN_MARGIN),MAX(WIN_MARGIN),AVG(WIN_MARGIN),COUNT(DISTINCT MAN_OF_THE_MATCH)
                         FROM Match;""",conn)
result3
#return total of win margins for all the winners in season 9
result4 = pd.read_sql("""SELECT SUM(WIN_MARGIN)
                         FROM Match
                         WHERE SEASON_ID = 9;""",conn)
result4
# Out:
#    SUM(WIN_MARGIN)
# 0              920

# %%
#read tables from the dataset into data frame
Matches = pd.read_sql("""SELECT *
                         FROM Match;""",conn)
"""**conclution - **
- 12 Numeric features (Integer and Numeric)and one categorical feature (text)
-3 columns with null features
"""

Matches.head()
"""**conclutiom-**
-12 NUWERIC FEATURES INTEGER (Nunreric and integer) and three categorical features (text)
-3 columns with null expressions
"""
#get the average win margins for all the wining teams for season 9
result1 = pd.read_sql("""SELECT AVG(WIN_MARGIN),Match_Winner
                         FROM Match
                         WHERE SEASON_ID = 9
                         group by Match_Winner;""",conn)
display(result1)

#get the count of the venues for season 9
result2 = pd.read_sql("""SELECT COUNT(DISTINCT VENUE_ID)
                         FROM Match
                         WHERE SEASON_ID = 9;""",conn)
display(result2)
#get the minimum ,maximum and average win margin
#also get the total number of players who have recieved man of the match throughout all the seasons
result3 = pd.read_sql("""SELECT MIN(WIN_MARGIN),MAX(WIN_MARGIN),AVG(WIN_MARGIN),COUNT(DISTINCT MAN_OF_THE_MATCH)
                         FROM Match;""",conn)
display(result3)
#return total of win margins for all the winners in season 9
result4 = pd.read_sql("""SELECT SUM(WIN_MARGIN)
                         FROM Match
                         WHERE SEASON_ID = 9;""",conn)
display(result4)
# Out:
#    AVG(WIN_MARGIN)  Match_Winner
# 0         8.375000             1
# 1        34.555556             2
# 2        11.250000             4
# 3        10.428571             6
# 4        19.571429             7
# 5        15.636364            11
# 6        14.600000            12
# 7         4.666667            13
#    COUNT(DISTINCT VENUE_ID)
# 0                        11
#    MIN(WIN_MARGIN)  MAX(WIN_MARGIN)  AVG(WIN_MARGIN)  \
# 0                1              144        17.350352
#
#    COUNT(DISTINCT MAN_OF_THE_MATCH)
# 0                               187
#    SUM(WIN_MARGIN)
# 0              920

# %%
import pandas as pd

#read tables from the dataset into data frame
matches = pd.read_sql("""SELECT *
                         FROM Match;""",conn)
"""**conclution - **
- 12 Numeric features (Integer and Numeric)and one categorical feature (text)
-3 columns with null features
"""

matches.head()
"""**conclutiom-**
-12 NUWERIC FEATURES INTEGER (Nunreric and integer) and three categorical features (text)
-3 columns with null expressions
"""
#get the average win margins for all the wining teams for season 9
result1 = pd.read_sql("""SELECT AVG(WIN_MARGIN),Match_Winner
                         FROM Match
                         WHERE SEASON_ID = 9
                         group by Match_Winner;""",conn)
display(result1)

#get the count of the venues for season 9
result2 = pd.read_sql("""SELECT COUNT(DISTINCT VENUE_ID)
                         FROM Match
                         WHERE SEASON_ID = 9;""",conn)
display(result2)
#get the minimum ,maximum and average win margin
#also get the total number of players who have recieved man of the match throughout all the seasons
result3 = pd.read_sql("""SELECT MIN(WIN_MARGIN),MAX(WIN_MARGIN),AVG(WIN_MARGIN),COUNT(DISTINCT MAN_OF_THE_MATCH)
                         FROM Match;""",conn)
display(result3)
#return total of win margins for all the winners in season 9
result4 = pd.read_sql("""SELECT SUM(WIN_MARGIN)
                         FROM Match
                         WHERE SEASON_ID = 9;""",conn)
display(result4)
# Out:
#    AVG(WIN_MARGIN)  Match_Winner
# 0         8.375000             1
# 1        34.555556             2
# 2        11.250000             4
# 3        10.428571             6
# 4        19.571429             7
# 5        15.636364            11
# 6        14.600000            12
# 7         4.666667            13
#    COUNT(DISTINCT VENUE_ID)
# 0                        11
#    MIN(WIN_MARGIN)  MAX(WIN_MARGIN)  AVG(WIN_MARGIN)  \
# 0                1              144        17.350352
#
#    COUNT(DISTINCT MAN_OF_THE_MATCH)
# 0                               187
#    SUM(WIN_MARGIN)
# 0              920
